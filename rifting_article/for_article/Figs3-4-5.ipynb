# %% [markdown]
# # Post processing and visualizing mandyoc data
#
# The following notebook allows the user to reproduce Figures 3, 4 and 5.

# %%
#increase the display size to 95% of window width
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
display(HTML("<style>.output_result { max-width:95% !important; }</style>"))


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import interp1d
import glob
import os
import sys
import pylab as pl
import xarray as xr
import pymp
import mpl_toolkits.axisartist
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
import string
import matplotlib.cm as cm
from cmcrameri import cm as cr

local_path = os.getcwd()

sys.path.insert(0, f"{local_path}/functions")
from mandyocIO import read_datasets, change_dataset, plot_property, find_nearest, plot_tracked_particles_depth_coded, plot_ptt_paths_depth_coded
# Out:
# <style>.container { width:95% !important; }</style>
# <style>.output_result { max-width:95% !important; }</style>

# %% [markdown]
# # How to plot
#
# ## In the following cell, you must inform:
#  - Which Figure you wish to plot by comment/uncomment the `fig_to_plot` options

# %%
fig_to_plot = 'Fig3'
# fig_to_plot = 'Fig4'
# fig_to_plot = 'Fig5'

#Set scenario path
scenarios_path = local_path.split('/')
scenarios_path = f"{'/'.join(scenarios_path[:-1])}/scenarios"


if(fig_to_plot=='Fig3'):
    hcrust = 35.0e3 #m
    print(f"Comparing 35 km thick crust with v = 1 cm/yr: 1w, 1s, 2w, 2s")
    scenarios = [
                f"{scenarios_path}/1w_Ho35W1",
                f"{scenarios_path}/1s_Ho35S1",
                f"{scenarios_path}/2w_He35W1",
                f"{scenarios_path}/2s_He35S1",
                ]
if(fig_to_plot=='Fig4'):
    hcrust = 35.0e3 #m
    print(f"Comparing 35 km thick crust with v = 2 cm/yr: 4w, 4s, 5w, 5s")
    scenarios = [
                f"{scenarios_path}/4w_Ho35W2",
                f"{scenarios_path}/4s_Ho35S2",
                f"{scenarios_path}/5w_He35W2",
                f"{scenarios_path}/5s_He35S2",
                ]
if(fig_to_plot=='Fig5'):
    hcrust = 40.0e3 #m
    print(f"Comparing 40 km thick crust v = 1 and 2 cm/yr: 3w, 3s, 6w, 6s")
    scenarios = [
                f"{scenarios_path}/3w_Ho40W1",
                f"{scenarios_path}/3s_Ho40S1",
                f"{scenarios_path}/6w_Ho40W2",
                f"{scenarios_path}/6s_Ho40S2",
                ]

plot_isotherms = True

if(plot_isotherms):
    clean_plot=False
else:
    clean_plot = True

datasets = [#Properties from mandyoc. Comment/uncomment to select properties of the dataset
            'density',
            'radiogenic_heat',
            'pressure',
            'strain',
            'strain_rate',
            'surface',
            'temperature',
            'viscosity'
            ]

properties = [#Properties from mandyoc. Comment/uncomment to select which ones you would like to plot
            #  'density',
            #  'radiogenic_heat',
             'lithology',
            # 'pressure',
            #  'strain',
            #  'strain_rate',
            #  'temperature',
            #  'temperature_anomaly',
            #  'surface',
            #  'viscosity'
             ]

new_datasets = change_dataset(properties, datasets)

to_remove = []
remove_density=False
if ('density' not in properties): #used to plot air/curst interface
        properties.append('density')
        new_datasets = change_dataset(properties, datasets)
        to_remove.append('density')

if ('surface' not in properties): #used to plot air/curst interface
        properties.append('surface')
        new_datasets = change_dataset(properties, datasets)
        to_remove.append('surface')

if (plot_isotherms): #add datasets needed to plot isotherms
    if ('temperature' not in new_datasets):
        properties.append('temperature')
        new_datasets = change_dataset(properties, datasets)
        to_remove.append('temperature')

if(clean_plot): #a clean plot
    new_datasets = change_dataset(properties, datasets)

for item in to_remove:
    properties.remove(item)

dataset0 = read_datasets(scenarios[0], new_datasets)
dataset1 = read_datasets(scenarios[1], new_datasets)
dataset2 = read_datasets(scenarios[2], new_datasets)
dataset3 = read_datasets(scenarios[3], new_datasets)

# Normalize velocity values
if ("velocity_x" and "velocity_z") in dataset0.data_vars:
    v_max = np.max((dataset0.velocity_x**2 + dataset0.velocity_z**2)**(0.5))    
    dataset0.velocity_x[:] = dataset0.velocity_x[:] / v_max
    dataset0.velocity_z[:] = dataset0.velocity_z[:] / v_max

if ("velocity_x" and "velocity_z") in dataset1.data_vars:
    v_max = np.max((dataset1.velocity_x**2 + dataset1.velocity_z**2)**(0.5))    
    dataset1.velocity_x[:] = dataset1.velocity_x[:] / v_max
    dataset1.velocity_z[:] = dataset1.velocity_z[:] / v_max

if ("velocity_x" and "velocity_z") in dataset2.data_vars:
    v_max = np.max((dataset2.velocity_x**2 + dataset2.velocity_z**2)**(0.5))    
    dataset2.velocity_x[:] = dataset2.velocity_x[:] / v_max
    dataset2.velocity_z[:] = dataset2.velocity_z[:] / v_max


Nx = int(dataset0.nx)
Nz = int(dataset0.nz)
Lx = float(dataset0.lx)
Lz = float(dataset0.lz)

x = np.linspace(0, Lx/1000.0, Nx)
z = np.linspace(Lz/1000.0, 0, Nz)
xx, zz  = np.meshgrid(x, z)

# print(f"\n{dataset0.info}")

trackdataset0 = xr.open_dataset(f"{scenarios[0]}/_track_xzPT_all_steps.nc")
trackdataset1 = xr.open_dataset(f"{scenarios[1]}/_track_xzPT_all_steps.nc")
trackdataset2 = xr.open_dataset(f"{scenarios[2]}/_track_xzPT_all_steps.nc")
trackdataset3 = xr.open_dataset(f"{scenarios[3]}/_track_xzPT_all_steps.nc")

#PTt data from McCarthy et al. (2020) and Muntener et al. (2009)
McCarthy_data = pd.read_excel(f"PTt_Data/McCarthy_Fig9_datasets.xlsx")
Muntener_data = pd.read_excel(f"PTt_Data/Muntener_Fig16_datasets.xlsx")
Johanesen_data = pd.read_excel(f"PTt_Data/Johanesen_Fig7_datasets.xlsx")
Girardeau_data = pd.read_excel(f"PTt_Data/Girardeau_Fig12_datasets.xlsx")
Ballay_data = pd.read_excel(f"PTt_Data/Ballay_datasets.xlsx")
Suire_data = pd.read_excel(f"PTt_Data/Suire_FigIV.4_datasets.xlsx")
# Out:
# Comparing 35 km thick crust with v = 1 cm/yr: 1w, 1s, 2w, 2s

# %%
##############################################################################################################
#Set mandyoc property

prop = 'lithology'

# instants = [40, 30, 20, 10, 0] #Myr
instants = [40, 20, 10, 0] #Myr

plt.close('all')

fig_height = (3.0/2.0)*(len(instants) + 5) #6 minimum
fig = plt.figure(figsize=(18, fig_height), constrained_layout=True)

mosaic = """
         ABCD
         EFGH
         IJKL
         MNOP
         QRST
         """

axs = fig.subplot_mosaic(mosaic, gridspec_kw={'height_ratios':[0.5,
                                                               0.5,
                                                               0.5,
                                                               0.5,
                                                               1.0
                                                              ]
                                             }
                        )

alphabet = list(string.ascii_uppercase)
idxs = np.asarray(alphabet[0: len(instants)*len(scenarios)]) #starting at A subplot
idxs_aux = idxs.reshape(len(instants), len(scenarios))

i = 0


if(prop != 'surface'): # you can customize
    xlims = [600, 1600]
    ylims = [-130, 40]
    plot_particles = False
else: #for surface plot
    xmin = 0
    xmax = float(dataset0.isel(time=i).lx) / 1.0E3 #- 200
    xlims = [xmin, xmax]
    ylims = [-1.5, 1.5]

topo_from_density = True
plot_other_particles = False

color_lower_crust = 'xkcd:brown'
color_mlit_upper='xkcd:bright purple'
color_mlit_intermediate='xkcd:dark green'
color_mlit_lower='xkcd:bright orange'

for instant, i in zip(instants, range(len(instants))):
    idx0 = find_nearest(dataset0.time, instant)
    idx1 = find_nearest(dataset1.time, instant)
    idx2 = find_nearest(dataset2.time, instant) 
    idx3 = find_nearest(dataset3.time, instant) 

    if(instant == instants[-1]):
        plot_colorbar = True
    else:
        plot_colorbar = False

    plot_property(dataset0.isel(time=idx0), prop, xlims, ylims, scenarios[0],
             fig,
             axs[idxs_aux[i, 0]],
             plot_isotherms = plot_isotherms,
             topo_from_density = topo_from_density,
             plot_particles = plot_particles,
             particle_size = 0.2,
             particle_marker = ".",
             ncores = 20,
             isotherms = [500, 800, 1300],
             plot_colorbar=False,
            )
    
    plot_tracked_particles_depth_coded(trackdataset0, axs[idxs_aux[i, 0]], idx0, hcrust=hcrust, markersize=4,
                                       plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                                       color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

    plot_property(dataset1.isel(time=idx1), prop, xlims, ylims, scenarios[1],
             fig,
             axs[idxs_aux[i, 1]],
             plot_isotherms = plot_isotherms,
             topo_from_density = topo_from_density,
             plot_particles = plot_particles,
             particle_size = 0.2,
             particle_marker = ".",
             ncores = 20,
             isotherms = [500, 800, 1300],
             plot_colorbar=False,
            )

    plot_tracked_particles_depth_coded(trackdataset1, axs[idxs_aux[i, 1]], idx1, hcrust=hcrust, markersize=4,
                                       plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                                       color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

    plot_property(dataset2.isel(time=idx2), prop, xlims, ylims, scenarios[2],
             fig,
             axs[idxs_aux[i, 2]],
             plot_isotherms = plot_isotherms,
             topo_from_density = topo_from_density,
             plot_particles = plot_particles,
             particle_size = 0.2,
             particle_marker = ".",
             ncores = 20,
             isotherms = [500, 800, 1300],
             plot_colorbar=False,
            )
    
    plot_tracked_particles_depth_coded(trackdataset2, axs[idxs_aux[i, 2]], idx2, hcrust=hcrust, markersize=4,
                                       plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                                       color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

    plot_property(dataset3.isel(time=idx3), prop, xlims, ylims, scenarios[3],
             fig,
             axs[idxs_aux[i, 3]],
             plot_isotherms = plot_isotherms,
             topo_from_density = topo_from_density,
             plot_particles = plot_particles,
             particle_size = 0.2,
             particle_marker = ".",
             ncores = 20,
             isotherms = [500, 800, 1300],
             plot_colorbar=plot_colorbar,
             bbox_to_anchor=(0.82,#horizontal position respective to parent_bbox or "loc" position
                            0.3,# vertical position
                            0.19,# width
                            0.40),
            )
    
    plot_tracked_particles_depth_coded(trackdataset3, axs[idxs_aux[i, 3]], idx3, hcrust=hcrust, markersize=4,
                                       plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                                       color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)



color_other_particles='xkcd:black'
size_other_particles=2

idxs_ptts = np.asarray(alphabet[len(instants)*len(scenarios): len(instants)*len(scenarios)+len(scenarios)])

# scale_correction = 1.0
scale_correction = 1.0e-3
alpha_lines = 0.1
alpha_points = 1.0
plot_ptt_paths_depth_coded(trackdataset0, axs[idxs_ptts[0]], instants, scale_correction, hcrust=hcrust, alpha_lines=alpha_lines, alpha_points=alpha_points,
                            plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                            color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

plot_ptt_paths_depth_coded(trackdataset1, axs[idxs_ptts[1]], instants, scale_correction, hcrust=hcrust, alpha_lines=alpha_lines, alpha_points=alpha_points,
                            plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                            color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

plot_ptt_paths_depth_coded(trackdataset2, axs[idxs_ptts[2]], instants, scale_correction, hcrust=hcrust, alpha_lines=alpha_lines, alpha_points=alpha_points,
                            plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                            color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

plot_ptt_paths_depth_coded(trackdataset3, axs[idxs_ptts[3]], instants, scale_correction, hcrust=hcrust, alpha_lines=alpha_lines, alpha_points=alpha_points,
                            plot_lower_crust_particles=False, plot_mantle_lithosphere_particles=True, plot_asthenosphere_particles=True,
                            color_lower_crust=color_lower_crust, color_mlit_upper=color_mlit_upper, color_mlit_intermediate=color_mlit_intermediate, color_mlit_lower=color_mlit_lower)

fsize = 14

ylims = np.array([0, 4000])

axs[idxs_ptts[0]].set_ylabel('Pressure (GPa)', fontsize=fsize)
# for letter in ['Q', 'R', 'S', 'T']:
# for letter in ['U', 'V', 'W', 'X']:

def plot_arrow_head(ax, x, y, color='xkcd:cerulean blue', zorder=90):
    """
    Plot an arrow head at the end of a line segment.
        """
    dx = x[-1] - x[-2]
    dy = y[-1] - y[-2]
    head_width = 0.1# 0.05 * (max(y) - min(y)) if max(y) != min(y) else 0.1
    # print(head_width)
    # head_width = 2
    ax.arrow(x[-2], y[-2], dx, dy, length_includes_head=True, head_width=head_width, head_length=30, color=color, zorder=zorder)


########################################################################################################################################################
#                                                    P-T paths from McCarthy et al. (2020)                                                             #
# P‐T paths recorded by exhumed mantle domains at OCTs along the Western Tethys.                                                                       #
# Cold exhumation paths related to the exhumation of cold SCLM are from Borghini et al. (2011), Montanini et al. (2006), and Müntener et al. (2010).   #
# Hot exhumation path related to pervasive and upper melt percolation during rifting from Piccardo et al. (2009) and Müntener et al. (2010).         #
########################################################################################################################################################

ColdPath1T = McCarthy_data.ColdPath1T.values[~np.isnan(McCarthy_data.ColdPath1T.values)]
ColdPath1P = McCarthy_data.ColdPath1P.values[~np.isnan(McCarthy_data.ColdPath1P.values)]*100*scale_correction #kbar to MPa and to GPa conversion
ColdPath2T = McCarthy_data.ColdPath2T.values[~np.isnan(McCarthy_data.ColdPath2T.values)]
ColdPath2P = McCarthy_data.ColdPath2P.values[~np.isnan(McCarthy_data.ColdPath2P.values)]*100*scale_correction
ColdPath3T = McCarthy_data.ColdPath3T.values[~np.isnan(McCarthy_data.ColdPath3T.values)]
ColdPath3P = McCarthy_data.ColdPath3P.values[~np.isnan(McCarthy_data.ColdPath3P.values)]*100*scale_correction

HotPath1T = McCarthy_data.HotPath1T.values[~np.isnan(McCarthy_data.HotPath1T.values)]
HotPath1P = McCarthy_data.HotPath1P.values[~np.isnan(McCarthy_data.HotPath1P.values)]*100*scale_correction
HotPath2T = McCarthy_data.HotPath2T.values[~np.isnan(McCarthy_data.HotPath2T.values)]
HotPath2P = McCarthy_data.HotPath2P.values[~np.isnan(McCarthy_data.HotPath2P.values)]*100*scale_correction

SeamountPeridotiteT = McCarthy_data.SeamountPeridotiteT.values[~np.isnan(McCarthy_data.SeamountPeridotiteT.values)]
SeamountPeridotiteP = McCarthy_data.SeamountPeridotiteP.values[~np.isnan(McCarthy_data.SeamountPeridotiteP.values)]*100*scale_correction
uppererror = McCarthy_data.SeamountPeridotiteSigmaP1.values[~np.isnan(McCarthy_data.SeamountPeridotiteSigmaP1.values)]*100*scale_correction
lowererror = McCarthy_data.SeamountPeridotiteSigmaP2.values[~np.isnan(McCarthy_data.SeamountPeridotiteSigmaP2.values)]*100*scale_correction
asymmetric_error = [lowererror, uppererror]

########################################################################################################################################################
#                                                    P-T paths from Müntener et al. (2009)                                                             #
# P‐T paths recorded by exhumed mantle domains at OCTs along the Western Tethys.                                                                       #
########################################################################################################################################################
LowerPlattaDashedT = Muntener_data.LowerPlattaDashedPathT.values[~np.isnan(Muntener_data.LowerPlattaDashedPathT.values)]
LowerPlattaDashedP = Muntener_data.LowerPlattaDashedPathP.values[~np.isnan(Muntener_data.LowerPlattaDashedPathP.values)] #MPa
LowerPlattaFillT = Muntener_data.LowerPlattaFillPathT.values[~np.isnan(Muntener_data.LowerPlattaFillPathT.values)]
LowerPlattaFillP = Muntener_data.LowerPlattaFillPathP.values[~np.isnan(Muntener_data.LowerPlattaFillPathP.values)] #MPa


UpperPlattaT = Muntener_data.UpperPlattaPathT.values[~np.isnan(Muntener_data.UpperPlattaPathT.values)]
UpperPlattaP = Muntener_data.UpperPlattaPathP.values[~np.isnan(Muntener_data.UpperPlattaPathP.values)] #MPa

MalencoTotalpT = Muntener_data.MalencoTotalpPathT.values[~np.isnan(Muntener_data.MalencoTotalpPathT.values)]
MalencoTotalP = Muntener_data.MalencoTotalpPathP.values[~np.isnan(Muntener_data.MalencoTotalpPathP.values)] #MPa

#########################################################################################################################################################
#                                                    P-T paths from Johanesen et al. (2022)                                                             #
# P‐T paths recorded by exhumed mantle domains at OCTs along the Western Tethys.                                                                        #
#########################################################################################################################################################
##PTt Paths
#Garnet-spinel Mylonites
GMPathT = Johanesen_data.GMPathT.values[~np.isnan(Johanesen_data.GMPathT.values)]
GMPathP = Johanesen_data.GMPathP.values[~np.isnan(Johanesen_data.GMPathP.values)]*scale_correction #MPa to GPa conversion

#Spinel Tectonites
STPathT = Johanesen_data.STPathT.values[~np.isnan(Johanesen_data.STPathT.values)]
STPathP = Johanesen_data.STPathP.values[~np.isnan(Johanesen_data.STPathP.values)]*scale_correction #MPa to GPa conversion

#Granular Spinel Peridotites
GSPathT = Johanesen_data.GSPathT.values[~np.isnan(Johanesen_data.GSPathT.values)]
GSPathP = Johanesen_data.GSPathP.values[~np.isnan(Johanesen_data.GSPathP.values)]*scale_correction #MPa to GPa conversion

#Plagioclase Tectonites
PTPathT = Johanesen_data.PTPathT.values[~np.isnan(Johanesen_data.PTPathT.values)]
PTPathP = Johanesen_data.PTPathP.values[~np.isnan(Johanesen_data.PTPathP.values)]*scale_correction #MPa to GPa conversion

##Wet and Dry Peridotite Solidi
WetPeridotiteSolidusT = Johanesen_data.WetPeridotiteSolidusT.values[~np.isnan(Johanesen_data.WetPeridotiteSolidusT.values)]
WetPeridotiteSolidusP = Johanesen_data.WetPeridotiteSolidusP.values[~np.isnan(Johanesen_data.WetPeridotiteSolidusP.values)]*scale_correction
DryPeridotiteSolidusT = Johanesen_data.DryPeridotiteSolidusT.values[~np.isnan(Johanesen_data.DryPeridotiteSolidusT.values)]
DryPeridotiteSolidusP = Johanesen_data.DryPeridotiteSolidusP.values[~np.isnan(Johanesen_data.DryPeridotiteSolidusP.values)]*scale_correction

color_ronda = 'xkcd:cobalt blue'

#########################################################################################################################################################
#                                                    P-T paths from Girardeau et al. (1988)                                                             #
# P‐T paths recorded by exhumed mantle domains at OCTs along the Iberia Margin.                                                                         #
#########################################################################################################################################################

H637AT = Girardeau_data.H637T.values[~np.isnan(Girardeau_data.H637T.values)]
H637AP = Girardeau_data.H637P.values[~np.isnan(Girardeau_data.H637P.values)] #GPa

############################################################################################################################################
#                                                    P-T-t paths of Ballay PhD                                                             #
# P‐T-t paths recorded by exhumed mantle domains at OCTs along the SW Australian margin                                                    #
############################################################################################################################################

Diamantina_tec_T = Ballay_data.T_tectonic.values[~np.isnan(Ballay_data.T_tectonic.values)]
Diamantina_tec_P = Ballay_data.P_tectonic.values[~np.isnan(Ballay_data.P_tectonic.values)]
Diamantina_mag_T = Ballay_data.T_magma.values[~np.isnan(Ballay_data.T_magma.values)]
Diamantina_mag_P = Ballay_data.P_magma.values[~np.isnan(Ballay_data.P_magma.values)]

#########################################################################################################################################################
#                                                    P-T fields from Suire et al. (in prep)                                                             #
# P‐T-t paths recorded by exhumed mantle domains at OCTs along the Iberia margin and P-T estimation for Newfoundland margin                             #
#########################################################################################################################################################

Iberia_T_melt = Suire_data.T_melt.values[~np.isnan(Suire_data.T_melt.values)]
Iberia_P_melt = Suire_data.P_melt.values[~np.isnan(Suire_data.P_melt.values)]
Iberia_T_fast = Suire_data.T_fast.values[~np.isnan(Suire_data.T_fast.values)]
Iberia_P_fast = Suire_data.P_fast.values[~np.isnan(Suire_data.P_fast.values)]
NF_T = Suire_data.T_NF.values[~np.isnan(Suire_data.T_NF.values)]
NF_P = Suire_data.P_NF.values[~np.isnan(Suire_data.P_NF.values)]
sigmaT_NF = Suire_data.sigmaT_NF.values[~np.isnan(Suire_data.sigmaT_NF.values)]
sigmaP_NF = Suire_data.sigmaP_NF.values[~np.isnan(Suire_data.sigmaP_NF.values)]

color_NF = 'xkcd:bright blue'

## Shaded Fields
#Spinel Mylonite
SPMylFieldT = Johanesen_data.SPMylFieldT.values[~np.isnan(Johanesen_data.SPMylFieldT.values)]
SPMylFieldP = Johanesen_data.SPMylFieldP.values[~np.isnan(Johanesen_data.SPMylFieldP.values)]*scale_correction

#Porphs in Mylonite
PorphsMylFieldT = Johanesen_data.PorphsMylFieldT.values[~np.isnan(Johanesen_data.PorphsMylFieldT.values)]
PorphsMylFieldP = Johanesen_data.PorphsMylFieldP.values[~np.isnan(Johanesen_data.PorphsMylFieldP.values)]*scale_correction

#Porphs in Tectonite/Granular
PorphsTectGranFieldT = Johanesen_data.PorphsTectGranFieldT.values[~np.isnan(Johanesen_data.PorphsTectGranFieldT.values)]
PorphsTectGranFieldP = Johanesen_data.PorphsTectGranFieldP.values[~np.isnan(Johanesen_data.PorphsTectGranFieldP.values)]*scale_correction

#Plagioclase Field
PLFieldT = Johanesen_data.PLFieldT.values[~np.isnan(Johanesen_data.PLFieldT.values)]
PLFieldP = Johanesen_data.PLFieldP.values[~np.isnan(Johanesen_data.PLFieldP.values)]*scale_correction

zorder_realPTt = 80

xghosts = [-10,-10]
yghosts = [-10,-10]

#####################################
# CREATING LEGENDS FOR PTT SUBPLOTS #
#####################################

idx_layers_labels = 0

color_lower_crust='xkcd:brown'

axs[idxs_ptts[idx_layers_labels]].plot(xghosts, yghosts, '.', color=color_mlit_upper, label='Upper Lithospheric Mantle')
axs[idxs_ptts[idx_layers_labels]].plot(xghosts, yghosts, '.', color=color_mlit_intermediate, label='Intermediate Lithospheric Mantle')
axs[idxs_ptts[idx_layers_labels]].plot(xghosts, yghosts, '.', color=color_mlit_lower, label='Lower Lithospheric Mantle')
axs[idxs_ptts[idx_layers_labels]].legend(loc='upper left', ncol=1, fontsize=9, handlelength=1, handletextpad=0.2, labelcolor='linecolor', title='Lagrangian Particles')

idx_solidi_curves_labels = 1
axs[idxs_ptts[idx_solidi_curves_labels]].plot(xghosts, yghosts, '-.', color='xkcd:gray', label='Wet Peridotite Solidus')
axs[idxs_ptts[idx_solidi_curves_labels]].plot(xghosts, yghosts, '--', color='xkcd:gray', label='Dry Peridotite Solidus')
axs[idxs_ptts[idx_solidi_curves_labels]].plot(xghosts, yghosts, '-', color='xkcd:gray', label='Spinel-Plagioclase Facies')
axs[idxs_ptts[idx_solidi_curves_labels]].legend(loc='upper left', ncol=1, fontsize=9, title='Solidi Curves and Facies', handletextpad=0.2, labelcolor='linecolor')

idx_path_types_labels = 2

color_Iberia_path = 'xkcd:emerald green'
color_Diamantina =  'xkcd:brown'
color_WTc = 'xkcd:cobalt blue'
color_WTh = 'xkcd:scarlet'

linestyle_Iberia_path = '--'
linestyle_Diamantina = '--'
linestyle_WTc = '--'
linestyle_WTh = '--'

axs[idxs_ptts[idx_path_types_labels]].plot(xghosts, yghosts, linestyle=linestyle_Iberia_path, color=color_Iberia_path, label='Iberia Paths')
axs[idxs_ptts[idx_path_types_labels]].plot(xghosts, yghosts, linestyle=linestyle_Diamantina, color=color_Diamantina, label='Diamantina Paths')
axs[idxs_ptts[idx_path_types_labels]].plot(xghosts, yghosts, linestyle=linestyle_WTc, color=color_WTc, label='Western Tethys Cold Paths')
axs[idxs_ptts[idx_path_types_labels]].plot(xghosts, yghosts, linestyle=linestyle_WTh, color=color_WTh, label='Western Tethys Hot Paths')

axs[idxs_ptts[idx_path_types_labels]].errorbar(-10, -10, yerr=1, fmt='o', markersize=3, color='xkcd:bright red', capsize=3, label='Terre Adélie Seamount B\nPeridotite')
axs[idxs_ptts[idx_path_types_labels]].errorbar(-10, -10, xerr=1, yerr=1, fmt='o', markersize=3, color=color_NF, capsize=3, label='Newfoundland\nHarzburgite')

axs[idxs_ptts[idx_path_types_labels]].legend(loc='upper left', ncol=1, fontsize=9, handletextpad=0.5, labelcolor='linecolor', title='P-T Data')

idx_fields_labels = 3

axs[idxs_ptts[idx_fields_labels]].plot(xghosts, yghosts, '-', color='xkcd:scarlet', label='Spinel Field')
axs[idxs_ptts[idx_fields_labels]].plot(xghosts, yghosts, '-', color='xkcd:cerulean blue', label='Plagioclase Field')
axs[idxs_ptts[idx_fields_labels]].legend(loc='upper left', ncol=1, fontsize=9, handlelength=0, handletextpad=0, labelcolor='linecolor', title='Shaded Fields')

for letter in list(idxs_ptts):

    #Plot P-T paths from McCarthy et al. (2020) - Western Tethys Cold and Hot Paths
    axs[letter].plot(ColdPath1T, ColdPath1P, linestyle=linestyle_WTc, color=color_WTc, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], ColdPath1T, ColdPath1P, color=color_WTc)

    axs[letter].plot(HotPath1T, HotPath1P, linestyle=linestyle_WTh, color=color_WTh, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], HotPath1T, HotPath1P, color=color_WTh, zorder=zorder_realPTt)

    axs[letter].plot(HotPath2T, HotPath2P, linestyle=linestyle_WTh, color=color_WTh, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], HotPath2T, HotPath2P, color=color_WTh, zorder=zorder_realPTt)

    #Plot P-T paths from Müntener et al. (2009) - Western Tethys Cold Paths
    axs[letter].plot(LowerPlattaDashedT, LowerPlattaDashedP, linestyle=linestyle_WTc, color=color_WTc, zorder=zorder_realPTt)
    axs[letter].plot(LowerPlattaFillT, LowerPlattaFillP, linestyle=linestyle_WTc, color=color_WTc, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], LowerPlattaFillT, LowerPlattaFillP, color=color_WTc, zorder=zorder_realPTt)

    axs[letter].plot(UpperPlattaT, UpperPlattaP, linestyle=linestyle_WTc, color=color_WTc, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], UpperPlattaT, UpperPlattaP, color=color_WTc, zorder=zorder_realPTt)

    axs[letter].plot(MalencoTotalpT, MalencoTotalP, linestyle=linestyle_WTc, color=color_WTc, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], MalencoTotalpT, MalencoTotalP, color=color_WTc, zorder=zorder_realPTt)

    #plotting P-T-t paths of Ballay PhD
    axs[letter].plot(Diamantina_tec_T, Diamantina_tec_P, linestyle=linestyle_Diamantina, color=color_Diamantina, zorder=zorder_realPTt)#, label='Diamantina Tectonic Path')
    plot_arrow_head(axs[letter], Diamantina_tec_T, Diamantina_tec_P, color=color_Diamantina, zorder=zorder_realPTt)

    axs[letter].plot(Diamantina_mag_T, Diamantina_mag_P, linestyle=linestyle_Diamantina, color=color_Diamantina, zorder=zorder_realPTt)#, label='Diamantina Magmatic Path')
    plot_arrow_head(axs[letter], Diamantina_mag_T, Diamantina_mag_P, color=color_Diamantina, zorder=zorder_realPTt)

    #Plotting P-T-t paths and P-T estimation from Suire et al. (in prep) to Iberia Margin and Newfoundland Margin
    axs[letter].plot(Iberia_T_melt, Iberia_P_melt, linestyle=linestyle_Iberia_path, color=color_Iberia_path, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], Iberia_T_melt, Iberia_P_melt, color=color_Iberia_path, zorder=zorder_realPTt)
    axs[letter].plot(Iberia_T_fast, Iberia_P_fast, linestyle=linestyle_Iberia_path, color=color_Iberia_path, zorder=zorder_realPTt)
    plot_arrow_head(axs[letter], Iberia_T_fast, Iberia_P_fast, color=color_Iberia_path, zorder=zorder_realPTt)

    axs[letter].errorbar(NF_T, NF_P, xerr=sigmaT_NF, yerr=sigmaP_NF, fmt='o', color=color_NF, markersize=3, capsize=5, zorder=zorder_realPTt)
    
    #plotting fields and other data of McCarthy et al. (2020)
    axs[letter].plot(McCarthy_data.SpPlFaciesT, McCarthy_data.SpPlFaciesP*100*scale_correction, '-', color='xkcd:gray', label='Spinel-Plagioclase Facies', zorder=70)
    
    axs[letter].errorbar(SeamountPeridotiteT, SeamountPeridotiteP, yerr=asymmetric_error, fmt='o', markersize=3, color='xkcd:bright red', capsize=5, zorder=zorder_realPTt)

    #Plot fields of Johanesen et al. (2022)
    axs[letter].plot(WetPeridotiteSolidusT, WetPeridotiteSolidusP, '-.', color='xkcd:gray', zorder=70)#), label='Wet Peridotite Solidus')
    axs[letter].plot(DryPeridotiteSolidusT, DryPeridotiteSolidusP, '--', color='xkcd:gray', zorder=70)#), label='Dry Peridotite Solidus')

    axs[letter].plot(SPMylFieldT, SPMylFieldP, '-', label='Spinel Field', color='xkcd:scarlet', zorder=70)
    axs[letter].fill(SPMylFieldT, SPMylFieldP, color='xkcd:scarlet', alpha=0.1, zorder=70)

    axs[letter].plot(PLFieldT, PLFieldP, '-', color='xkcd:cerulean blue', label='Plagioclase Field', zorder=70)
    axs[letter].fill(PLFieldT, PLFieldP, color='xkcd:cerulean blue', alpha=0.1, zorder=70)

    axs[letter].tick_params(axis='both', labelsize=fsize-2)
    axs[letter].grid('-k', alpha=0.7)
    axs[letter].set_xlabel(r'Temperature ($^{\circ}$C)', fontsize=fsize)
    axs[letter].set_xlim([0, 1500])
    axs[letter].set_ylim(ylims*scale_correction)
    if letter != idxs_ptts[0]:
        axs[letter].set_yticklabels([])

    #creating depth axis to PTt plot
    ax1 = axs[letter].twinx()
    ax1.set_ylim(ylims/30)
    ax1.tick_params(axis='y', labelsize=fsize-2)
    ax1.set_ylabel('Depth (km)', fontsize=fsize) if letter == idxs_ptts[-1] else ax1.set_yticklabels([])
        

##########################
#Set plot details
##########################
#Titles
# axs['A'].set_title(r'Reference Scenario')

xpos = 0.0
ypos = 1.035

xpos1 = 0.5
ypos1 = 1.45

fsize = 16
if(fig_to_plot == 'Fig3'):
    agroup = f"Group 1w"
    bgroup = f"Group 1s"
    cgroup = f"Group 2w"
    dgroup = f"Group 2s"
    v = 1

if(fig_to_plot == 'Fig4'):
    agroup = f"Group 4w"
    bgroup = f"Group 4s"
    cgroup = f"Group 5w"
    dgroup = f"Group 5s"
    v = 2

if(fig_to_plot == 'Fig5'):
    agroup = f"Group 3w"
    bgroup = f"Group 3s"
    cgroup = f"Group 6w"
    dgroup = f"Group 6s"
    
if(fig_to_plot != "Fig5"):
    axs['A'].text(xpos, ypos, f"a) $v$ = {int(v)} cm/yr", transform=axs['A'].transAxes, fontsize=14)
    axs['A'].text(xpos1, ypos1, f"{agroup}\nHomogeneous lit.\nWeak lower crust\nCrust 35 km thick", transform=axs['A'].transAxes, ha='center', va='center', fontsize=fsize)

    axs['B'].text(xpos, ypos, f"b) $v$ = {int(v)} cm/yr", transform=axs['B'].transAxes, fontsize=fsize)
    axs['B'].text(xpos1, ypos1, f"{bgroup}\nHomogeneous lit.\nStrong lower crust\nCrust 35 km thick", transform=axs['B'].transAxes, ha='center', va='center', fontsize=fsize)

    axs['C'].text(xpos, ypos, f"c) $v$ = {int(v)} cm/yr", transform=axs['C'].transAxes, fontsize=14)
    axs['C'].text(xpos1, ypos1, f"{cgroup}\nHeterogeneous lit.\nWeak lower crust\nCrust 35 km thick", transform=axs['C'].transAxes, ha='center', va='center', fontsize=fsize)

    axs['D'].text(xpos, ypos, f"d) $v$ = {int(v)} cm/yr", transform=axs['D'].transAxes, fontsize=14)
    axs['D'].text(xpos1, ypos1, f"{dgroup}\nHeterogeneous lit.\nStrong lower crust\nCrust 35 km thick", transform=axs['D'].transAxes, ha='center', va='center', fontsize=fsize)

else:
    axs['A'].text(xpos, ypos, f"a) $v$ = 1 cm/yr", transform=axs['A'].transAxes, fontsize=14)
    axs['A'].text(xpos1, ypos1, f"{agroup}\nHomogeneous lit.\nWeak lower crust\nCrust 40 km thick", transform=axs['A'].transAxes, ha='center', va='center', fontsize=fsize)

    axs['B'].text(xpos, ypos, f"b) $v$ = 1 cm/yr", transform=axs['B'].transAxes, fontsize=14)
    axs['B'].text(xpos1, ypos1, f"{bgroup}\nHomogeneous lit.\nStrong lower crust\nCrust 40 km thick", transform=axs['B'].transAxes, ha='center', va='center', fontsize=fsize)

    axs['C'].text(xpos, ypos, f"c) $v$ = 2 cm/yr", transform=axs['C'].transAxes, fontsize=14)
    axs['C'].text(xpos1, ypos1, f"{cgroup}\nHomogeneous lit.\nWeak lower crust\nCrust 40 km thick", transform=axs['C'].transAxes, ha='center', va='center', fontsize=fsize)

    axs['D'].text(xpos, ypos, f"d) $v$ = 2 cm/yr", transform=axs['D'].transAxes, fontsize=14)
    axs['D'].text(xpos1, ypos1, f"{dgroup}\nHomogeneous lit.\nStrong lower crust\nCrust 40 km thick", transform=axs['D'].transAxes, ha='center', va='center', fontsize=fsize)

line_labels = np.asarray(list(string.ascii_lowercase)[0: 4])
label_fsize = 14
for i in range(len(instants)):
    ax_name = idxs_aux[i, 2]
    axs[idxs_aux[i, 0]].set_ylabel('Depth (km)', fontsize=label_fsize)
    axs[idxs_aux[i, 1]].set_yticklabels([])
    axs[idxs_aux[i, 2]].set_yticklabels([])
    axs[idxs_aux[i, 3]].set_yticklabels([])

    if(i == len(instants) - 1):
        axs[idxs_aux[i, 0]].set_xlabel('Distance (km)', fontsize=label_fsize)
        axs[idxs_aux[i, 1]].set_xlabel('Distance (km)', fontsize=label_fsize)
        axs[idxs_aux[i, 2]].set_xlabel('Distance (km)', fontsize=label_fsize)
        axs[idxs_aux[i, 3]].set_xlabel('Distance (km)', fontsize=label_fsize)
        
    else:
        axs[idxs_aux[i, 0]].set_xticklabels([])
        axs[idxs_aux[i, 1]].set_xticklabels([])
        axs[idxs_aux[i, 2]].set_xticklabels([])
        axs[idxs_aux[i, 3]].set_xticklabels([])

# fig_format = 'png'
fig_format = 'jpeg'
print(f"Saving {fig_to_plot}.{fig_format}")
fig.savefig(f"figures/{fig_to_plot}.{fig_format}", dpi=300)
# Out:
# Saving Fig3.jpeg
