# %%
import pygmt
import os
import geopandas as gpd
import matplotlib as plt
import matplotlib_inline
path = os.getcwd().split('/')
machine_path = '/'+path[1]+'/'+path[2]
# pygmt.show_versions()

fig = pygmt.Figure()

region = [-180, 180, -90, 90]
# projection = 'Cyl_stere/30/-20/12c'
# projection = 'W12c'
projection = 'Kf12c' 
# projection = 'N12c'
# projection = 

#plot coast
fig.coast(region=region,
          projection=projection,
          resolution='h',
          shorelines=True,
          frame=True, #set frame and axes attributes.
          water='LIGHTCYAN',
          land='245')

#creating basemap
fig.basemap(region=region,
            projection=projection,
            frame="ag"
            )

#read shapefiles data
path = f"{machine_path}/opt/global_tectonics/plates&provinces/shp"
filename = f"{path}/cratons.shp"
gdf = gpd.read_file(filename)

fig.plot(filename, fill='PERU')

fig.show()

# %%
#read shapefiles data
path = f"{machine_path}/opt/global_tectonics/plates&provinces/shp"
filename = f"{path}/cratons.shp"
gdf = gpd.read_file(filename)

# %%
# for data in gdf[gdf["prov_group"] == "Sao Francisco"]
all_data = []

all_data.append(gdf[gdf["continent"] == "South America"])

for data_shp in all_data:
    fig.plot(data=data_shp, color='red')

# for i in range(len(gdf.prov_group)):
#     print(gdf.prov_group[i])

# %%
gdf
# Out:
#       id           prov_name      prov_type  \
# 0      4        Limpopo Belt         shield
# 1      7     Tanzania Craton         craton
# 2     13        Eglab Shield         shield
# 3     16       Uganda Craton         craton
# 4     17      Rwenzori Block         shield
# ..   ...                 ...            ...
# 109  499     Voronezh Massif         shield
# 110   30        Itremo Block  orogenic belt
# 111   29  Antenanarivo Block  orogenic belt
# 112  204  Kirgiz-Terskey Arc   volcanic arc
# 113  876     Vestfold Craton         craton
#
#                                prov_ref           prov_group      lastorogen  \
# 0               doi:10.1144/jgs2012-059      Kalahari Craton         Limpopo
# 1               doi:10.1144/jgs2012-059         Congo Craton        cratonic
# 2                   doi:10.1144/SP297.1  West African Craton            BETA
# 3                doi:10.1130/GES00179.1         Congo Craton        cratonic
# 4                doi:10.1130/GES00179.1         Congo Craton          GRANTS
# ..                                  ...                  ...             ...
# 109  doi:10.1144/GSL.MEM.2006.032.01.01        Baltic Shield  Inner-Nunanian
# 110   doi:10.1016/S0301-9268(03)00064-0                 None    East African
# 111   doi:10.1016/S0301-9268(03)00064-0                 None    East African
# 112           10.1144/0016-76492006-022      Kazakh Orocline      Kazakhstan
# 113                                None                 None        cratonic
#
#       continent   crust_type           area  PLATEID1  ...  \
# 0        Africa  continental  174925.498061    7001.0  ...
# 1        Africa  continental  493169.110359    7004.0  ...
# 2        Africa  continental  273892.228522    7007.0  ...
# 3        Africa  continental  102592.173469    7004.0  ...
# 4        Africa  continental   57567.469427    7004.0  ...
# ..          ...          ...            ...       ...  ...
# 109      Europe  continental  480704.027573       NaN  ...
# 110      Africa  continental   86766.716040       NaN  ...
# 111      Africa  continental  306205.365740       NaN  ...
# 112        Asia  continental   29186.416716       NaN  ...
# 113  Antarctica  continental  204208.606622       NaN  ...
#
#                      conjugate1  PLATEID2  comment RECON_METH  L_PLATE  \
# 0                          None       NaN     None       None     None
# 1                          None       NaN     None       None     None
# 2                          None       NaN     None       None     None
# 3                          None       NaN     None       None     None
# 4                          None       NaN     None       None     None
# ..                          ...       ...      ...        ...      ...
# 109                        None       NaN     None       None     None
# 110                        None       NaN     None       None     None
# 111  Southern Granulite Terrane       NaN     None       None     None
# 112                        None       NaN     None       None     None
# 113            Singhbhum Craton       NaN     None       None     None
#
#     R_PLATE SPREAD_ASY IMPORT_AGE reworked  \
# 0      None       None       None      yes
# 1      None       None       None       no
# 2      None       None       None      yes
# 3      None       None       None       no
# 4      None       None       None      yes
# ..      ...        ...        ...      ...
# 109    None       None       None      yes
# 110    None       None       None      yes
# 111    None       None       None      yes
# 112    None       None       None      yes
# 113    None       None       None       no
#
#                                               geometry
# 0    POLYGON ((31.13268 -22.59015, 31.07209 -22.590...
# 1    POLYGON ((37.07504 -6.58558, 36.91057 -6.85180...
# 2    POLYGON ((-10.05422 22.93878, -10.05422 23.175...
# 3    POLYGON ((34.79746 -0.15043, 34.54206 -0.13933...
# 4    POLYGON ((35.89679 -0.33920, 35.46372 -0.35031...
# ..                                                 ...
# 109  POLYGON ((41.97345 48.13229, 41.33687 48.30665...
# 110  POLYGON ((43.86789 -17.42695, 44.10932 -17.718...
# 111  POLYGON ((47.94389 -13.89262, 48.39836 -14.085...
# 112  POLYGON ((71.54146 42.85547, 71.94236 42.88762...
# 113  POLYGON ((79.91786 -69.70129, 79.91786 -69.701...
#
# [114 rows x 23 columns]
